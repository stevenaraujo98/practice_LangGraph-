# %%
from langchain_core.prompts import PromptTemplate

template = """\
# Instrucciones para el Asistente de IA

Recuerda que hoy es {fecha_actual}

## Rol
Eres un experto en marketing digital con 10 años de experiencia.

## Tarea
Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocándote en el llamado a la acción (CTA).

## Texto del Anuncio
{texto_anuncio}

## Formato de Salida
- *Sugerencia 1:* [Tu primera sugerencia]
- *Sugerencia 2:* [Tu segunda sugerencia]
- *Sugerencia 3:* [Tu tercera sugerencia]
"""


# aconsejan los XML con los tags
# PromptTemplate nos deja definir variables para definirlas luego 
prompt_template = PromptTemplate.from_template(template)
# cuando se le da formart, se pasan las variables
prompt = prompt_template.format(fecha_actual="2025-09-20", texto_anuncio="Este es un anuncio de prueba")
print(prompt)
# Out:
# # Instrucciones para el Asistente de IA
#
# Recuerda que hoy es 2025-09-20
#
# ## Rol
# Eres un experto en marketing digital con 10 años de experiencia.
#
# ## Tarea
# Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocándote en el llamado a la acción (CTA).
#
# ## Texto del Anuncio
# Este es un anuncio de prueba
#
# ## Formato de Salida
# - *Sugerencia 1:* [Tu primera sugerencia]
# - *Sugerencia 2:* [Tu segunda sugerencia]
# - *Sugerencia 3:* [Tu tercera sugerencia]

# %%
prompt = prompt_template.format()
print(prompt)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 prompt = prompt_template.format()
#       2 print(prompt)
#
# File c:\Users\steve\Documents\Cursos\Crear_Agentes_de_ AI_con_LangGraph\first\.venv\Lib\site-packages\langchain_core\prompts\prompt.py:198, in PromptTemplate.format(self, **kwargs)
#     189 """Format the prompt with the inputs.
#     190
#     191 Args:
#    (...)    195     A formatted string.
#     196 """
#     197 kwargs = self._merge_partial_and_user_variables(**kwargs)
# --> 198 return DEFAULT_FORMATTER_MAPPING[self.template_format](self.template, **kwargs)
#
# File ~\anaconda3\envs\langgraph\Lib\string.py:190, in Formatter.format(self, format_string, *args, **kwargs)
#     189 def format(self, format_string, /, *args, **kwargs):
# --> 190     return self.vformat(format_string, args, kwargs)
#
# ...

# %%
import datetime
today = datetime.datetime.now().strftime("%Y-%m-%d")
prompt_template = PromptTemplate.from_template(template, partial_variables={"fecha_actual": today}) # le puedo mandar variables parciales o por defecto
prompt = prompt_template.format(texto_anuncio="Este es un anuncio de prueba")
print(prompt)
# Out:
# # Instrucciones para el Asistente de IA
#
# Recuerda que hoy es 2025-12-14
#
# ## Rol
# Eres un experto en marketing digital con 10 años de experiencia.
#
# ## Tarea
# Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocándote en el llamado a la acción (CTA).
#
# ## Texto del Anuncio
# Este es un anuncio de prueba
#
# ## Formato de Salida
# - *Sugerencia 1:* [Tu primera sugerencia]
# - *Sugerencia 2:* [Tu segunda sugerencia]
# - *Sugerencia 3:* [Tu tercera sugerencia]

# %%
template = """\
Your are a helpful that responds to the user's 
{% if name %}
The user's name is {{ name }} and you can call them by that name
{% endif -%}
The user's message is: {{ user_message }}
"""
# Con el "-" antes del cierre de la etiqueta de control, se elimina el espacio en blanco adicional que normalmente se incluiría en la salida.

# langchain soporta mas templates como jinja2 que es lo que usa django para sus templates, con sus condicionales y loops
prompt_template = PromptTemplate.from_template(template, template_format="jinja2") 
# prompt = prompt_template.format(user_message="Como puedo mejorar mi sitio web?") # como no recibe name, no muestra esa parte 
# prompt = prompt_template.format(user_message="Como puedo mejorar mi sitio web?", name= None) # como no recibe name, no muestra esa parte 
# prompt = prompt_template.format(user_message="Como puedo mejorar mi sitio web?", name= "") # como no recibe name, no muestra esa parte 
prompt = prompt_template.format(user_message="Como puedo mejorar mi sitio web?", name= "Juan") # como no recibe name, no muestra esa parte 
print(prompt)
# Out:
# Your are a helpful that responds to the user's
#
# The user's name is Juan and you can call them by that name
# The user's message is: Como puedo mejorar mi sitio web?
